# %% [markdown]
# # 3MTT FINAL PROJECT
# ### TOPIC:
# ## LAPTOP PRICE
# ### BY:
# ## Maryam Bashir Mustapha
# ### FELLOW ID:
# ## FE/23/48518708

# %% [markdown]
# # DATA CLEANING AND PROCESSING OF LAPTOP PRICE DATASET

# %% [markdown]
# ## 1. IMPORTING LIBERARIES

# %%
# importing liberary
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %% [markdown]
# ## 2. IMPORTING DATASET FROM EXCEL TO PYTHON

# %%
# importing dataset
df = pd.read_excel("Dirty Data.xlsx")

# %%
# displaying first 10 element in dataset
df.head(10)
# Out:
#     Brand          Model  Screen_size   Color Harddisk             CPU    Ram  \
# 0  Apple_    MacBook Air  13.3 Inches  Silver   256 GB         Unknown   8 GB
# 1   Apple    MacBook Air  15.3 Inches   Black   256 GB         Unknown   8 GB
# 2    Acer  A315-24P-R7VH  15.6 Inches  Silver   128 GB         Ryzen 3   8 GB
# 3   Apple    MacBook Pro  13.3 Inches    Gray   256 GB         Unknown   8 GB
# 4    Acer      CB315-3HT  15.6 Inches  Silver    64 GB   Celeron N4020   4 GB
# 5    ASUS  ROG Strix G16    16 Inches    Gray   512 GB         Core i7  16 GB
# 6    acer   A515-56-347N  15.6 Inches  Silver   128 GB  Core I3 1115G4   8 GB
# 7    acer  AN515-58-57Y8  15.6 Inches   Black   512 GB         Core i5  16 GB
# 8     HP…       Notebook    14 Inches    Gray     1 TB   Ryzen 3 3250U  16 GB
# 9    ROKC      Ideapad 3  15.6 Inches    Gray  1000 GB   Intel Core i5  20 GB
#
#                 OS    Special_features    Graphics Graphics_card cpu_speed  \
# 0           Mac OS    Backlit Keyboard  Integrated         Intel   3.7 GHz
# 1           Mac OS    Backlit Keyboard  Integrated         Intel   4.5 GHz
# 2     Windows 11 S    Backlit Keyboard  Integrated         Intel   1.8 GHz
# 3           Mac OS    Backlit Keyboard  Integrated         Intel   3.7 GHz
# 4        Chrome OS      Support Stylus  Integrated         Intel   2.2 GHz
# 5  Windows 11 Home    Backlit Keyboard   Dedicated         Intel   4.5 GHz
# 6     Windows 11 S        Amazon Alexa  Integrated         Intel   2.2 GHz
# 7  Windows 11 Home    Backlit Keyboard   Dedicated         Intel   3.7 GHz
# 8       Windows 11  Anti Glare Coating  Integrated         Intel  2.66 GHz
# 9       Windows 11    Backlit Keyboard  Integrated         Intel   3.7 GHz
#
#    Rating    Price
# 0     4.8   689.99
# 1     4.8  1144.48
# 2     4.5   299.99
# 3     4.7   965.08
# 4     4.4   239.99
# 5     4.4  1274.03
# 6     4.3   299.99
# 7     4.4   814.77
# 8     4.4   379.99
# 9     4.3   639.99

# %%
# displaying last five(tail) in dataset
df.tail()
# Out:
#       Brand                 Model  Screen_size  Color Harddisk      CPU  \
# 352    acer          A514-55-545G    14 Inches   Gray   512 GB  Core i5
# 353  Lenovo       Lenovo Thinkpad    14 Inches  Black   256 GB  Core i5
# 354      HP    Elite Dragonfly G3  13.5 Inches  Black   512 GB  Core i5
# 355     MSI  Bravo 17 C7VFK-039US  17.3 Inches  Black     1 TB  Ryzen 7
# 356  Lenovo       Lenovo Thinkpad    14 Inches  Black   256 GB  Core i5
#
#        Ram               OS   Special_features          Graphics  \
# 352   8 GB  Windows 11 Home   Backlit Keyboard        Integrated
# 353   8 GB   Windows 10 Pro   Backlit Keyboard        Integrated
# 354  16 GB   Windows 10 Pro  Anti-glare Screen  Iris Xe Graphics
# 355  32 GB   Windows 11 Pro   Backlit Keyboard         Dedicated
# 356   8 GB   Windows 10 Pro   Backlit Keyboard        Integrated
#
#               Graphics_card cpu_speed  Rating    Price
# 352                   Intel   2.4 GHz     4.3   668.55
# 353                   Intel   2.4 GHz     3.7   883.58
# 354  Intel Iris Xe Graphics   4.5 GHz     4.0  2039.00
# 355                   Intel   4.5 GHz     4.3  1499.00
# 356                   Intel   2.4 GHz     3.7   883.58

# %% [markdown]
# ## 3. DISPLAYING DATASET BASIC INFORMATION

# %%
# displaying dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             357 non-null    object
#  1   Model             357 non-null    object
#  2   Screen_size       357 non-null    object
#  3   Color             357 non-null    object
#  4   Harddisk          357 non-null    object
#  5   CPU               357 non-null    object
#  6   Ram               357 non-null    object
#  7   OS                357 non-null    object
#  8   Special_features  357 non-null    object
#  9   Graphics          357 non-null    object
#  10  Graphics_card     357 non-null    object
#  11  cpu_speed         357 non-null    object
#  12  Rating            357 non-null    float64
#  13  Price             357 non-null    float64
# dtypes: float64(2), object(12)
# memory usage: 39.2+ KB

# %%
# displaying dataset file description
df.describe()
# Out:
#            Rating        Price
# count  357.000000   357.000000
# mean     4.219608  1061.258852
# std      0.674043   776.824857
# min      1.000000    57.990000
# 25%      4.100000   465.000000
# 50%      4.300000   883.580000
# 75%      4.500000  1576.570000
# max      5.000000  4762.760000

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ## 5. REMOVING DUPLICATES

# %%
# removing duplicates from the whole dataset
df = df.drop_duplicates()

# %%
# displaying parts where duplicates where removed
df.tail()
# Out:
#       Brand                 Model  Screen_size   Color Harddisk      CPU  \
# 351      HP      EliteBook 865 G9    16 Inches  Silver   512 GB  Ryzen 7
# 352    acer          A514-55-545G    14 Inches    Gray   512 GB  Core i5
# 353  Lenovo       Lenovo Thinkpad    14 Inches   Black   256 GB  Core i5
# 354      HP    Elite Dragonfly G3  13.5 Inches   Black   512 GB  Core i5
# 355     MSI  Bravo 17 C7VFK-039US  17.3 Inches   Black     1 TB  Ryzen 7
#
#        Ram               OS   Special_features              Graphics  \
# 351  16 GB   Windows 11 Pro  Anti-glare Screen  Radeon 680M Graphics
# 352   8 GB  Windows 11 Home   Backlit Keyboard            Integrated
# 353   8 GB   Windows 10 Pro   Backlit Keyboard            Integrated
# 354  16 GB   Windows 10 Pro  Anti-glare Screen      Iris Xe Graphics
# 355  32 GB   Windows 11 Pro   Backlit Keyboard             Dedicated
#
#                 Graphics_card cpu_speed  Rating    Price
# 351  AMD Radeon 680M Graphics   4.5 GHz     4.3  1427.99
# 352                     Intel   2.4 GHz     4.3   668.55
# 353                     Intel   2.4 GHz     3.7   883.58
# 354    Intel Iris Xe Graphics   4.5 GHz     4.0  2039.00
# 355                     Intel   4.5 GHz     4.3  1499.00

# %% [markdown]
# ## 6. DROPPING UNWANTED COLUMNS

# %%
# removing columns
df = df.drop(columns = "Model")

# %%
# displaying head to confirm removed column
df.head()
# Out:
#     Brand  Screen_size   Color Harddisk            CPU   Ram            OS  \
# 0  Apple_  13.3 Inches  Silver   256 GB        Unknown  8 GB        Mac OS
# 1   Apple  15.3 Inches   Black   256 GB        Unknown  8 GB        Mac OS
# 2    Acer  15.6 Inches  Silver   128 GB        Ryzen 3  8 GB  Windows 11 S
# 3   Apple  13.3 Inches    Gray   256 GB        Unknown  8 GB        Mac OS
# 4    Acer  15.6 Inches  Silver    64 GB  Celeron N4020  4 GB     Chrome OS
#
#    Special_features    Graphics Graphics_card cpu_speed  Rating    Price
# 0  Backlit Keyboard  Integrated         Intel   3.7 GHz     4.8   689.99
# 1  Backlit Keyboard  Integrated         Intel   4.5 GHz     4.8  1144.48
# 2  Backlit Keyboard  Integrated         Intel   1.8 GHz     4.5   299.99
# 3  Backlit Keyboard  Integrated         Intel   3.7 GHz     4.7   965.08
# 4    Support Stylus  Integrated         Intel   2.2 GHz     4.4   239.99

# %% [markdown]
# ## 7. REMOVING UNWANTED CHARACTERS IN COLUMNS

# %%
# removing unwanted characters from "Day_of_Week" column
df["Brand"] = df["Brand"].str.strip("..._/")

# %%
# displaying dataset to view removed characters
df.head(10)
# Out:
#    Brand  Screen_size   Color Harddisk             CPU    Ram  \
# 0  Apple  13.3 Inches  Silver   256 GB         Unknown   8 GB
# 1  Apple  15.3 Inches   Black   256 GB         Unknown   8 GB
# 2   Acer  15.6 Inches  Silver   128 GB         Ryzen 3   8 GB
# 3  Apple  13.3 Inches    Gray   256 GB         Unknown   8 GB
# 4   Acer  15.6 Inches  Silver    64 GB   Celeron N4020   4 GB
# 5   ASUS    16 Inches    Gray   512 GB         Core i7  16 GB
# 6   acer  15.6 Inches  Silver   128 GB  Core I3 1115G4   8 GB
# 7   acer  15.6 Inches   Black   512 GB         Core i5  16 GB
# 8    HP…    14 Inches    Gray     1 TB   Ryzen 3 3250U  16 GB
# 9   ROKC  15.6 Inches    Gray  1000 GB   Intel Core i5  20 GB
#
#                 OS    Special_features    Graphics Graphics_card cpu_speed  \
# 0           Mac OS    Backlit Keyboard  Integrated         Intel   3.7 GHz
# 1           Mac OS    Backlit Keyboard  Integrated         Intel   4.5 GHz
# 2     Windows 11 S    Backlit Keyboard  Integrated         Intel   1.8 GHz
# 3           Mac OS    Backlit Keyboard  Integrated         Intel   3.7 GHz
# 4        Chrome OS      Support Stylus  Integrated         Intel   2.2 GHz
# 5  Windows 11 Home    Backlit Keyboard   Dedicated         Intel   4.5 GHz
# 6     Windows 11 S        Amazon Alexa  Integrated         Intel   2.2 GHz
# 7  Windows 11 Home    Backlit Keyboard   Dedicated         Intel   3.7 GHz
# 8       Windows 11  Anti Glare Coating  Integrated         Intel  2.66 GHz
# 9       Windows 11    Backlit Keyboard  Integrated         Intel   3.7 GHz
#
#    Rating    Price
# 0     4.8   689.99
# 1     4.8  1144.48
# 2     4.5   299.99
# 3     4.7   965.08
# 4     4.4   239.99
# 5     4.4  1274.03
# 6     4.3   299.99
# 7     4.4   814.77
# 8     4.4   379.99
# 9     4.3   639.99

# %% [markdown]
# ## REPLACING UNWANTED ELEMENT IN BRAND COLUMN

# %%
df["Brand"] = df["Brand"].str.replace("HP…", "HP")

# %%
# displaying dataset to view removed characters
df.head(10)
# Out:
#    Brand  Screen_size   Color Harddisk             CPU    Ram  \
# 0  Apple  13.3 Inches  Silver   256 GB         Unknown   8 GB
# 1  Apple  15.3 Inches   Black   256 GB         Unknown   8 GB
# 2   Acer  15.6 Inches  Silver   128 GB         Ryzen 3   8 GB
# 3  Apple  13.3 Inches    Gray   256 GB         Unknown   8 GB
# 4   Acer  15.6 Inches  Silver    64 GB   Celeron N4020   4 GB
# 5   ASUS    16 Inches    Gray   512 GB         Core i7  16 GB
# 6   acer  15.6 Inches  Silver   128 GB  Core I3 1115G4   8 GB
# 7   acer  15.6 Inches   Black   512 GB         Core i5  16 GB
# 8     HP    14 Inches    Gray     1 TB   Ryzen 3 3250U  16 GB
# 9   ROKC  15.6 Inches    Gray  1000 GB   Intel Core i5  20 GB
#
#                 OS    Special_features    Graphics Graphics_card cpu_speed  \
# 0           Mac OS    Backlit Keyboard  Integrated         Intel   3.7 GHz
# 1           Mac OS    Backlit Keyboard  Integrated         Intel   4.5 GHz
# 2     Windows 11 S    Backlit Keyboard  Integrated         Intel   1.8 GHz
# 3           Mac OS    Backlit Keyboard  Integrated         Intel   3.7 GHz
# 4        Chrome OS      Support Stylus  Integrated         Intel   2.2 GHz
# 5  Windows 11 Home    Backlit Keyboard   Dedicated         Intel   4.5 GHz
# 6     Windows 11 S        Amazon Alexa  Integrated         Intel   2.2 GHz
# 7  Windows 11 Home    Backlit Keyboard   Dedicated         Intel   3.7 GHz
# 8       Windows 11  Anti Glare Coating  Integrated         Intel  2.66 GHz
# 9       Windows 11    Backlit Keyboard  Integrated         Intel   3.7 GHz
#
#    Rating    Price
# 0     4.8   689.99
# 1     4.8  1144.48
# 2     4.5   299.99
# 3     4.7   965.08
# 4     4.4   239.99
# 5     4.4  1274.03
# 6     4.3   299.99
# 7     4.4   814.77
# 8     4.4   379.99
# 9     4.3   639.99

# %% [markdown]
# # DATA PROCESSING

# %% [markdown]
# ## 8. CREATING A PIVOT TABLE

# %%
# creating pivot table
pivot_table_df = pd.pivot_table(df, values = ["Brand", "Ram", "Price"], index = "Harddisk", aggfunc = max)

# %% [markdown]
# ## 9. PLOTING PIVOT CHART

# %%
# ploting the pivot table
pivot_table_df.style.background_gradient(cmap = "cubehelix")
# Out:
# <style type="text/css">
# #T_02395_row0_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_02395_row1_col1 {
#   background-color: #d17f96;
#   color: #f1f1f1;
# }
# #T_02395_row2_col1 {
#   background-color: #0a030a;
#   color: #f1f1f1;
# }
# #T_02395_row3_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_02395_row4_col1 {
#   background-color: #181027;
#   color: #f1f1f1;
# }
# #T_02395_row5_col1 {
#   background-color: #163f4e;
#   color: #f1f1f1;
# }
# #T_02395_row6_col1 {
#   background-color: #c1cff3;
#   color: #000000;
# }
# #T_02395_row7_col1, #T_02395_row13_col1 {
#   background-color: #130919;
#   color: #f1f1f1;
# }
# #T_02395_row8_col1 {
#   background-color: #1f6741;
#   color: #f1f1f1;
# }
# #T_02395_row9_col1 {
#   background-color: #2b6f39;
#   color: #f1f1f1;
# }
# #T_02395_row10_col1 {
#   background-color: #757b33;
#   color: #f1f1f1;
# }
# #T_02395_row11_col1 {
#   background-color: #c97b7f;
#   color: #f1f1f1;
# }
# #T_02395_row12_col1 {
#   background-color: #ac7954;
#   color: #f1f1f1;
# }
# #T_02395_row14_col1 {
#   background-color: #0f0611;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_02395">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02395_level0_col0" class="col_heading level0 col0" >Brand</th>
#       <th id="T_02395_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_02395_level0_col2" class="col_heading level0 col2" >Ram</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Harddisk</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02395_level0_row0" class="row_heading level0 row0" >1 TB</th>
#       <td id="T_02395_row0_col0" class="data row0 col0" >acer</td>
#       <td id="T_02395_row0_col1" class="data row0 col1" >4762.760000</td>
#       <td id="T_02395_row0_col2" class="data row0 col2" >64 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row1" class="row_heading level0 row1" >1000 GB</th>
#       <td id="T_02395_row1_col0" class="data row1 col0" >ROKC</td>
#       <td id="T_02395_row1_col1" class="data row1 col1" >2929.990000</td>
#       <td id="T_02395_row1_col2" class="data row1 col2" >32 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row2" class="row_heading level0 row2" >1000GB</th>
#       <td id="T_02395_row2_col0" class="data row2 col0" >HP</td>
#       <td id="T_02395_row2_col1" class="data row2 col1" >271.990000</td>
#       <td id="T_02395_row2_col2" class="data row2 col2" >4 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row3" class="row_heading level0 row3" >120 GB</th>
#       <td id="T_02395_row3_col0" class="data row3 col0" >Quality Refurbished Computers</td>
#       <td id="T_02395_row3_col1" class="data row3 col1" >159.000000</td>
#       <td id="T_02395_row3_col2" class="data row3 col2" >8 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row4" class="row_heading level0 row4" >128 GB</th>
#       <td id="T_02395_row4_col0" class="data row4 col0" >acer</td>
#       <td id="T_02395_row4_col1" class="data row4 col1" >548.000000</td>
#       <td id="T_02395_row4_col2" class="data row4 col2" >8 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row5" class="row_heading level0 row5" >16 GB</th>
#       <td id="T_02395_row5_col0" class="data row5 col0" >SAMSUNG</td>
#       <td id="T_02395_row5_col1" class="data row5 col1" >1099.990000</td>
#       <td id="T_02395_row5_col2" class="data row5 col2" >4 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row6" class="row_heading level0 row6" >2 TB</th>
#       <td id="T_02395_row6_col0" class="data row6 col0" >acer</td>
#       <td id="T_02395_row6_col1" class="data row6 col1" >3899.000000</td>
#       <td id="T_02395_row6_col2" class="data row6 col2" >8 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row7" class="row_heading level0 row7" >240 GB</th>
#       <td id="T_02395_row7_col0" class="data row7 col0" >Panasonic</td>
#       <td id="T_02395_row7_col1" class="data row7 col1" >420.000000</td>
#       <td id="T_02395_row7_col2" class="data row7 col2" >8 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row8" class="row_heading level0 row8" >256 GB</th>
#       <td id="T_02395_row8_col0" class="data row8 col0" >acer</td>
#       <td id="T_02395_row8_col1" class="data row8 col1" >1550.990000</td>
#       <td id="T_02395_row8_col2" class="data row8 col2" >8 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row9" class="row_heading level0 row9" >2TB</th>
#       <td id="T_02395_row9_col0" class="data row9 col0" >MSI</td>
#       <td id="T_02395_row9_col1" class="data row9 col1" >1699.000000</td>
#       <td id="T_02395_row9_col2" class="data row9 col2" >32 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row10" class="row_heading level0 row10" >32 GB</th>
#       <td id="T_02395_row10_col0" class="data row10 col0" >SAMSUNG</td>
#       <td id="T_02395_row10_col1" class="data row10 col1" >2199.000000</td>
#       <td id="T_02395_row10_col2" class="data row10 col2" >8 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row11" class="row_heading level0 row11" >4 TB</th>
#       <td id="T_02395_row11_col0" class="data row11 col0" >Lenovo</td>
#       <td id="T_02395_row11_col1" class="data row11 col1" >2819.000000</td>
#       <td id="T_02395_row11_col2" class="data row11 col2" >64 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row12" class="row_heading level0 row12" >512 GB</th>
#       <td id="T_02395_row12_col0" class="data row12 col0" >acer</td>
#       <td id="T_02395_row12_col1" class="data row12 col1" >2549.000000</td>
#       <td id="T_02395_row12_col2" class="data row12 col2" >8 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row13" class="row_heading level0 row13" >64 GB</th>
#       <td id="T_02395_row13_col0" class="data row13 col0" >acer</td>
#       <td id="T_02395_row13_col1" class="data row13 col1" >424.460000</td>
#       <td id="T_02395_row13_col2" class="data row13 col2" >8 GB</td>
#     </tr>
#     <tr>
#       <th id="T_02395_level0_row14" class="row_heading level0 row14" >65 GB</th>
#       <td id="T_02395_row14_col0" class="data row14 col0" >ASUS</td>
#       <td id="T_02395_row14_col1" class="data row14 col1" >349.950000</td>
#       <td id="T_02395_row14_col2" class="data row14 col2" >4 GB</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 10. DISPLAYING CLEANED DATASET

# %%
# displaying first ten elements of the dataset
df.head(10)
# Out:
#    Brand  Screen_size   Color Harddisk             CPU    Ram  \
# 0  Apple  13.3 Inches  Silver   256 GB         Unknown   8 GB
# 1  Apple  15.3 Inches   Black   256 GB         Unknown   8 GB
# 2   Acer  15.6 Inches  Silver   128 GB         Ryzen 3   8 GB
# 3  Apple  13.3 Inches    Gray   256 GB         Unknown   8 GB
# 4   Acer  15.6 Inches  Silver    64 GB   Celeron N4020   4 GB
# 5   ASUS    16 Inches    Gray   512 GB         Core i7  16 GB
# 6   acer  15.6 Inches  Silver   128 GB  Core I3 1115G4   8 GB
# 7   acer  15.6 Inches   Black   512 GB         Core i5  16 GB
# 8     HP    14 Inches    Gray     1 TB   Ryzen 3 3250U  16 GB
# 9   ROKC  15.6 Inches    Gray  1000 GB   Intel Core i5  20 GB
#
#                 OS    Special_features    Graphics Graphics_card cpu_speed  \
# 0           Mac OS    Backlit Keyboard  Integrated         Intel   3.7 GHz
# 1           Mac OS    Backlit Keyboard  Integrated         Intel   4.5 GHz
# 2     Windows 11 S    Backlit Keyboard  Integrated         Intel   1.8 GHz
# 3           Mac OS    Backlit Keyboard  Integrated         Intel   3.7 GHz
# 4        Chrome OS      Support Stylus  Integrated         Intel   2.2 GHz
# 5  Windows 11 Home    Backlit Keyboard   Dedicated         Intel   4.5 GHz
# 6     Windows 11 S        Amazon Alexa  Integrated         Intel   2.2 GHz
# 7  Windows 11 Home    Backlit Keyboard   Dedicated         Intel   3.7 GHz
# 8       Windows 11  Anti Glare Coating  Integrated         Intel  2.66 GHz
# 9       Windows 11    Backlit Keyboard  Integrated         Intel   3.7 GHz
#
#    Rating    Price
# 0     4.8   689.99
# 1     4.8  1144.48
# 2     4.5   299.99
# 3     4.7   965.08
# 4     4.4   239.99
# 5     4.4  1274.03
# 6     4.3   299.99
# 7     4.4   814.77
# 8     4.4   379.99
# 9     4.3   639.99

# %% [markdown]
# ## 11. EXPORTING CLEANED DATASET FROM PYTHON TO EXCEL

# %%
# exporting dataset to my local machine for further analysis
df.to_excel(r"C:\Users\Dell\Desktop\3mtt_final_project_python_mumtee.xlsx",  index=False)
